# %%
from msdn import inference, evaluate

inference ('samples/IMG_0059591_squash(squash).jpg')
# Out:
# {'data': {'batch_size': 1,
#           'dataset': 'nia',
#           'dataset_option': 'normal',
#           'dataset_version': 'T0116',
#           'opts': 'options/data.yaml',
#           'use_region': False},
#  'dataset': 'nia',
#  'logs': {'dir_logs': 'msdn_02151609_T0116_1_iters_SGD',
#           'model_name': 'msdn',
#           'operation': ''},
#  'model': {'MPS_iter': 1,
#            'activation': 'relu',
#            'arch': 'FN_v4',
#            'bottleneck': True,
#            'cls_obj': 1.0,
#            'cls_pred': 2.0,
#            'dim_ho': 512,
#            'dim_hp': 512,
#            'dim_hr': 512,
#            'dim_mm': 256,
#            'dropout': 0,
#            'fusion': 'PI_v5',
#            'op': 'Sum',
#            'pool_size': 7,
#            'reg_obj': 0.5,
#            'rpn_opts': 'options/RPN/rpn.yaml',
#            'use_bias': True,
#            'use_loss_weight': True,
#            'use_shortcut': True},
#  'optim': {'clip_gradient': True,
# ...

# %%
print ('hello')
# Out:
# hello
